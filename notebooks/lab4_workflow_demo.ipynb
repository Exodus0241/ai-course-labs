# %% [markdown]
# # Лабораторная работа №4
#
# Демонстрация тестового вызова workflow automation через Python-клиент.

# %%
from src.api_client import load_workflow_settings
from src.webhook_handler import WorkflowClient

settings = load_workflow_settings()
client = WorkflowClient(base_url=settings.base_url, webhook_path=settings.application_webhook_path)
settings

# %%
client.check_workflow_status()
